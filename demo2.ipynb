# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
im = cv2.imread('../images/images/castara.jpeg')

# %%
plt.imshow(cv2.cvtColor(im,cv2.COLOR_BGR2RGB))

# %%
def imshow(title = 'Image',image = None, size = 7):
    w,h = image.shape[0], image.shape[1]
    aspect_ratio = w/h
    plt.figure(figsize=(size*aspect_ratio,size))
    plt.imshow(cv2.cvtColor(image,cv2.COLOR_BGR2RGB))
    plt.title(title)

# %%
imshow('Castara',im)

# %%
im.shape
# Out:
# (1280, 960, 3)

# %%
B,G,R = cv2.split(im)

# %%
G.shape
# Out:
# (1280, 960)

# %%
zeros=np.zeros(im.shape[:2],dtype='uint8')

# %%
zeros.shape
# Out:
# (1280, 960)

# %%
print(imshow('Blue',cv2.merge([B,zeros,zeros]),size=5))
print(imshow('Red',cv2.merge([zeros,zeros,R]),size=5))
print(imshow('Green',cv2.merge([zeros,G,zeros]),size=5))
imshow('Gray',x,size=5)
#plt.imshow('Gray',cv2.cvtColor(im,cv2.COLOR_BGR2GRAY))
# Out:
# None
# None
# None

# %%
x = cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
imshow('Gray',x)

# %%
merged = cv2.merge([B+100,G,R])
imshow('Blue enhanced',merged,size=7)

# %%
merged1 = cv2.merge([B-25,G-50,R+100])
imshow('Image',merged1,size=7)

# %%
plt.imshow(cv2.cvtColor(im,cv2.COLOR_BGR2HSV))

# %%
plt.imshow(cv2.cvtColor(im,cv2.COLOR_HSV2BGR))

# %%
plt.imshow(cv2.cvtColor(im,cv2.COLOR_HSV2RGB))

# %%
hsv_img = cv2.cvtColor(im,cv2.COLOR_BGR2HSV)

# %%
plt.imshow(cv2.cvtColor(hsv_img,cv2.COLOR_HSV2RGB))

# %%
imshow('Hue',hsv_img[:,:,0],size=7)
imshow('Saturation',hsv_img[:,:,1],size=7)
imshow('Value',hsv_img[:,:,2],size=7)

# %%
im1 = np.zeros([512,512,3],np.uint8)
grey_im1 = np.zeros([512,512],np.uint8)
imshow('Grey',grey_im1)
imshow('Black',im1,size=7)

# %%
x = cv2.line(im1,(0,0),(511,511),(0,255,0),5)
imshow('Image1',x)

# %%
x1 = cv2.line(im1,(0,500),(500,0),(0,0,255),5)
imshow('Image2',x1)

# %%
x1 = cv2.line(grey_im1,(0,512),(512,0),(255,255),5)
imshow('Image2',x1)

# %%
zer = np.zeros([512,512,3],np.uint8)
im = cv2.rectangle(zer,(100,200),(400,400),(127,50,185),5)
imshow('Image',im)

# %%
zer = np.zeros([1024,1024,3],np.uint8)

# %%
i1 = cv2.circle(zer,(250,250),100,(50,185.200),-1)
imshow('Circle',i1)

# %%
pts = np.array([[50,120],[300,200],[200,300],[150,250],[50,450]])
pts = pts.reshape(-2,1,2)

# %%
i1 = cv2.polylines(zer,[pts],True,(255,0,0),3)
imshow('Polygon',i1)

# %%
pts.shape
# Out:
# (5, 1, 2)

# %%
cv2.putText(zer,'Rajendra Bera',(50,200),cv2.FONT_HERSHEY_COMPLEX,5,(0,255,0))
imshow('Name',zer)
